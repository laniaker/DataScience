# %%
import pandas as pd
import requests
import os
import time
from trafilatura import fetch_url, extract
from urllib.parse import urlparse, urljoin

# ====================================================================
# KONFIGURATION
# ====================================================================

INPUT_FILE = "WikiNasdaq_100_constituents.csv"
OUTPUT_FILE = "nasdaq100_company_texts_V2.csv"
MAX_TEXT_LENGTH = 3000
REQUEST_TIMEOUT = 10 
# WICHTIG: Verzögerung, um Rate Limiting zu vermeiden (mind. 1-2 Sekunden empfohlen!)
SCRAPING_DELAY = 1.5 

# Liste der relativen Pfade, die nacheinander versucht werden
TARGET_PATHS = ['/company', '/about', '/investors', '/']

# ====================================================================
# FUNKTIONEN
# ====================================================================

def is_valid_url(url):
    """Prüft, ob die URL gültig und ein http/https-Schema verwendet."""
    if pd.isna(url) or str(url).lower() in ['n/a', 'nan']:
        return False
    try:
        result = urlparse(url)
        return all([result.scheme in ['http', 'https'], result.netloc])
    except ValueError:
        return False

def build_url(base_url, path):
    """Baut eine vollständige URL aus der Basis-URL und dem relativen Pfad."""
    if not base_url.endswith('/') and not path.startswith('/'):
        return base_url + '/' + path
    return urljoin(base_url, path)

def scrape_content_with_retry(base_url):
    """
    Versucht nacheinander, Inhalte von definierten Zielpfaden zu scrapen.
    """
    for path in TARGET_PATHS:
        url_to_scrape = build_url(base_url, path)
        print(f"   -> Versuche Pfad: {url_to_scrape}")
        
        try:
            # Füge einen kleinen Delay vor jedem Request ein
            time.sleep(SCRAPING_DELAY) 
            
            # Trafilatura lädt die Seite herunter
            downloaded = fetch_url(url_to_scrape)
            
            if downloaded:
                # Extrahieren des reinen Textes
                extracted_json = extract(downloaded, output_format='json', 
                                         include_comments=False,
                                         include_images=False,
                                         include_tables=False)
                
                if extracted_json:
                    data = json.loads(extracted_json)
                    text = data.get('text', '')
                    
                    # Logik: Wenn mehr als 100 Zeichen extrahiert wurden, nehmen wir den Inhalt an
                    if len(text) > 100 and not text.startswith("FEHLER_BEI_ABRUF"):
                        print(f"   -> ✅ Erfolg auf Pfad: {path}")
                        return text
            
        except requests.exceptions.Timeout:
            print(f"   -> ⚠️ Timeout beim Abruf von {url_to_scrape}")
            return "FEHLER_BEI_ABRUF: Timeout"
        except Exception as e:
            # Ignoriere allgemeine Fehler und versuche den nächsten Pfad
            continue

    return "KEIN_HAUPTINHALT_GEFUNDEN_NACH_FALLBACK"


# ====================================================================
# HAUPTSKRIPT
# ====================================================================

import json

# 1. Daten laden
df = pd.read_csv(INPUT_FILE)
df['Extracted_Text'] = None  # Neue Spalte initialisieren

print(f"Starte gezieltes Web-Scraping für {len(df)} Unternehmen...")

# 2. Schleife über alle Unternehmen
for index, row in df.iterrows():
    ticker = row['Ticker']
    website = row['Website']
    
    if not is_valid_url(website):
        df.loc[index, 'Extracted_Text'] = "URL_UNGÜLTIG"
        print(f"[{ticker}] ❌ URL ungültig. Überspringe.")
        continue

    print(f"\n--- [{ticker}] Starte Abruf: {website} ---")
    
    extracted_content = scrape_content_with_retry(website)
    
    # 3. Ergebnis verarbeiten
    if extracted_content.startswith("FEHLER_BEI_ABRUF"):
        df.loc[index, 'Extracted_Text'] = extracted_content
    elif extracted_content == "KEIN_HAUPTINHALT_GEFUNDEN_NACH_FALLBACK":
         df.loc[index, 'Extracted_Text'] = "KEIN_HAUPTINHALT_GEFUNDEN"
    else:
        # Text auf die maximale Länge kürzen und speichern
        short_text = extracted_content[:MAX_TEXT_LENGTH]
        df.loc[index, 'Extracted_Text'] = short_text
        print(f"[{ticker}] ✅ Endgültiger Erfolg! {len(short_text)} Zeichen extrahiert.")

print("\n====================================")
# 4. Resultierendes DataFrame speichern
df.to_csv(OUTPUT_FILE, index=False)
print(f"Datenextraktion abgeschlossen. Resultate gespeichert in: {OUTPUT_FILE}")
print("====================================")
# Out:
# Starte gezieltes Web-Scraping für 102 Unternehmen...
#
# --- [ADBE] Starte Abruf: https://www.adobe.com/ ---
#    -> Versuche Pfad: https://www.adobe.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [ADBE] ✅ Endgültiger Erfolg! 1927 Zeichen extrahiert.
#
# --- [AMD] Starte Abruf: https://www.amd.com/ ---
#    -> Versuche Pfad: https://www.amd.com/company
#    -> Versuche Pfad: https://www.amd.com/about
#    -> Versuche Pfad: https://www.amd.com/investors
#    -> Versuche Pfad: https://www.amd.com/
#
# --- [ABNB] Starte Abruf: https://www.airbnb.com/ ---
#    -> Versuche Pfad: https://www.airbnb.com/company
#    -> Versuche Pfad: https://www.airbnb.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [ABNB] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
# [GOOGL] ❌ URL ungültig. Überspringe.
# [GOOG] ❌ URL ungültig. Überspringe.
#
# --- [AMZN] Starte Abruf: https://www.amazon.com/ ---
#    -> Versuche Pfad: https://www.amazon.com/company
#    -> Versuche Pfad: https://www.amazon.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [AMZN] ✅ Endgültiger Erfolg! 1762 Zeichen extrahiert.
#
# --- [AEP] Starte Abruf: https://www.aep.com ---
#    -> Versuche Pfad: https://www.aep.com/company
#    -> Versuche Pfad: https://www.aep.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [AEP] ✅ Endgültiger Erfolg! 1224 Zeichen extrahiert.
#
# --- [AMGN] Starte Abruf: http://www.amgen.com/ ---
#    -> Versuche Pfad: http://www.amgen.com/company
#    -> Versuche Pfad: http://www.amgen.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [AMGN] ✅ Endgültiger Erfolg! 2131 Zeichen extrahiert.
#
# --- [ADI] Starte Abruf: https://www.analog.com/ ---
#    -> Versuche Pfad: https://www.analog.com/company
#    -> Versuche Pfad: https://www.analog.com/about
#    -> Versuche Pfad: https://www.analog.com/investors
#    -> Versuche Pfad: https://www.analog.com/
#
# --- [AAPL] Starte Abruf: https://apple.com ---
#    -> Versuche Pfad: https://apple.com/company
#    -> Versuche Pfad: https://apple.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [AAPL] ✅ Endgültiger Erfolg! 1258 Zeichen extrahiert.
#
# --- [AMAT] Starte Abruf: https://www.appliedmaterials.com/ ---
#    -> Versuche Pfad: https://www.appliedmaterials.com/company
#    -> Versuche Pfad: https://www.appliedmaterials.com/about
#    -> Versuche Pfad: https://www.appliedmaterials.com/investors
#    -> Versuche Pfad: https://www.appliedmaterials.com/
#    -> ✅ Erfolg auf Pfad: /
# [AMAT] ✅ Endgültiger Erfolg! 386 Zeichen extrahiert.
#
# --- [APP] Starte Abruf: https://www.applovin.com/ ---
#    -> Versuche Pfad: https://www.applovin.com/company
#    -> Versuche Pfad: https://www.applovin.com/about
#    -> Versuche Pfad: https://www.applovin.com/investors
#    -> Versuche Pfad: https://www.applovin.com/
#    -> ✅ Erfolg auf Pfad: /
# [APP] ✅ Endgültiger Erfolg! 386 Zeichen extrahiert.
#
# --- [ARM] Starte Abruf: https://www.arm.com/ ---
#    -> Versuche Pfad: https://www.arm.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [ARM] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [ASML] Starte Abruf: https://www.asml.com/ ---
#    -> Versuche Pfad: https://www.asml.com/company
#    -> Versuche Pfad: https://www.asml.com/about
#    -> Versuche Pfad: https://www.asml.com/investors
#    -> Versuche Pfad: https://www.asml.com/
#
# --- [AZN] Starte Abruf: http://www.astrazeneca.com/ ---
#    -> Versuche Pfad: http://www.astrazeneca.com/company
#    -> Versuche Pfad: http://www.astrazeneca.com/about
#    -> Versuche Pfad: http://www.astrazeneca.com/investors
#    -> Versuche Pfad: http://www.astrazeneca.com/
#
# --- [TEAM] Starte Abruf: https://www.atlassian.com/ ---
#    -> Versuche Pfad: https://www.atlassian.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [TEAM] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [ADSK] Starte Abruf: https://www.autodesk.com/ ---
#    -> Versuche Pfad: https://www.autodesk.com/company
#    -> Versuche Pfad: https://www.autodesk.com/about
#    -> Versuche Pfad: https://www.autodesk.com/investors
#    -> Versuche Pfad: https://www.autodesk.com/
#
# --- [ADP] Starte Abruf: http://www.adp.com/ ---
#    -> Versuche Pfad: http://www.adp.com/company
#    -> Versuche Pfad: http://www.adp.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [ADP] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [AXON] Starte Abruf: https://www.axon.com/ ---
#    -> Versuche Pfad: https://www.axon.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [AXON] ✅ Endgültiger Erfolg! 1882 Zeichen extrahiert.
#
# --- [BKR] Starte Abruf: https://www.bakerhughes.com/ ---
#    -> Versuche Pfad: https://www.bakerhughes.com/company
#    -> Versuche Pfad: https://www.bakerhughes.com/about
#    -> Versuche Pfad: https://www.bakerhughes.com/investors
#    -> Versuche Pfad: https://www.bakerhughes.com/
#    -> ✅ Erfolg auf Pfad: /
# [BKR] ✅ Endgültiger Erfolg! 2539 Zeichen extrahiert.
#
# --- [BIIB] Starte Abruf: https://www.biogen.com/ ---
#    -> Versuche Pfad: https://www.biogen.com/company
#    -> Versuche Pfad: https://www.biogen.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [BIIB] ✅ Endgültiger Erfolg! 464 Zeichen extrahiert.
#
# --- [BKNG] Starte Abruf: https://bookingholdings.com/ ---
#    -> Versuche Pfad: https://bookingholdings.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [BKNG] ✅ Endgültiger Erfolg! 1002 Zeichen extrahiert.
#
# --- [AVGO] Starte Abruf: https://www.broadcom.com/ ---
#    -> Versuche Pfad: https://www.broadcom.com/company
#    -> Versuche Pfad: https://www.broadcom.com/about
#    -> Versuche Pfad: https://www.broadcom.com/investors
#    -> Versuche Pfad: https://www.broadcom.com/
#
# --- [CDNS] Starte Abruf: https://www.cadence.com/ ---
#    -> Versuche Pfad: https://www.cadence.com/company
#    -> Versuche Pfad: https://www.cadence.com/about
#    -> Versuche Pfad: https://www.cadence.com/investors
#    -> Versuche Pfad: https://www.cadence.com/
#
# --- [CDW] Starte Abruf: http://www.cdw.com/ ---
#    -> Versuche Pfad: http://www.cdw.com/company
#    -> Versuche Pfad: http://www.cdw.com/about
#    -> Versuche Pfad: http://www.cdw.com/investors
#    -> Versuche Pfad: http://www.cdw.com/
#    -> ✅ Erfolg auf Pfad: /
# [CDW] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
# [CHTR] ❌ URL ungültig. Überspringe.
# [CTAS] ❌ URL ungültig. Überspringe.
#
# --- [CSCO] Starte Abruf: https://www.cisco.com/ ---
#    -> Versuche Pfad: https://www.cisco.com/company
#    -> Versuche Pfad: https://www.cisco.com/about
#    -> Versuche Pfad: https://www.cisco.com/investors
#    -> Versuche Pfad: https://www.cisco.com/
#    -> ✅ Erfolg auf Pfad: /
# [CSCO] ✅ Endgültiger Erfolg! 349 Zeichen extrahiert.
#
# --- [CCEP] Starte Abruf: https://www.cocacolaep.com/ ---
#    -> Versuche Pfad: https://www.cocacolaep.com/company
#    -> Versuche Pfad: https://www.cocacolaep.com/about
#    -> Versuche Pfad: https://www.cocacolaep.com/investors
#    -> Versuche Pfad: https://www.cocacolaep.com/
#
# --- [CTSH] Starte Abruf: https://www.cognizant.com ---
#    -> Versuche Pfad: https://www.cognizant.com/company
#    -> Versuche Pfad: https://www.cognizant.com/about
#    -> Versuche Pfad: https://www.cognizant.com/investors
#    -> Versuche Pfad: https://www.cognizant.com/
#    -> ✅ Erfolg auf Pfad: /
# [CTSH] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [CMCSA] Starte Abruf: http://corporate.comcast.com ---
#    -> Versuche Pfad: http://corporate.comcast.com/company
#    -> Versuche Pfad: http://corporate.comcast.com/about
#    -> Versuche Pfad: http://corporate.comcast.com/investors
#    -> Versuche Pfad: http://corporate.comcast.com/
#
# --- [CEG] Starte Abruf: https://www.constellation.com/ ---
#    -> Versuche Pfad: https://www.constellation.com/company
#    -> Versuche Pfad: https://www.constellation.com/about
#    -> Versuche Pfad: https://www.constellation.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [CEG] ✅ Endgültiger Erfolg! 1756 Zeichen extrahiert.
#
# --- [CPRT] Starte Abruf: https://www.copart.com/ ---
#    -> Versuche Pfad: https://www.copart.com/company
#    -> Versuche Pfad: https://www.copart.com/about
#    -> Versuche Pfad: https://www.copart.com/investors
#    -> Versuche Pfad: https://www.copart.com/
#
# --- [CSGP] Starte Abruf: https://www.costargroup.com/ ---
#    -> Versuche Pfad: https://www.costargroup.com/company
#    -> Versuche Pfad: https://www.costargroup.com/about
#    -> Versuche Pfad: https://www.costargroup.com/investors
#    -> Versuche Pfad: https://www.costargroup.com/
#
# --- [COST] Starte Abruf: https://www.costco.com/ ---
#    -> Versuche Pfad: https://www.costco.com/company
#    -> Versuche Pfad: https://www.costco.com/about
#    -> Versuche Pfad: https://www.costco.com/investors
#    -> Versuche Pfad: https://www.costco.com/
#
# --- [CRWD] Starte Abruf: https://www.crowdstrike.com/ ---
#    -> Versuche Pfad: https://www.crowdstrike.com/company
#    -> Versuche Pfad: https://www.crowdstrike.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [CRWD] ✅ Endgültiger Erfolg! 777 Zeichen extrahiert.
#
# --- [CSX] Starte Abruf: https://www.csx.com/ ---
#    -> Versuche Pfad: https://www.csx.com/company
#    -> Versuche Pfad: https://www.csx.com/about
#    -> Versuche Pfad: https://www.csx.com/investors
#    -> Versuche Pfad: https://www.csx.com/
#
# --- [DDOG] Starte Abruf: https://www.datadoghq.com/ ---
#    -> Versuche Pfad: https://www.datadoghq.com/company
#    -> Versuche Pfad: https://www.datadoghq.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [DDOG] ✅ Endgültiger Erfolg! 1360 Zeichen extrahiert.
#
# --- [DXCM] Starte Abruf: http://dexcom.com/ ---
#    -> Versuche Pfad: http://dexcom.com/company
#    -> Versuche Pfad: http://dexcom.com/about
#    -> Versuche Pfad: http://dexcom.com/investors
#    -> Versuche Pfad: http://dexcom.com/
#    -> ✅ Erfolg auf Pfad: /
# [DXCM] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [FANG] Starte Abruf: https://www.diamondbackenergy.com ---
#    -> Versuche Pfad: https://www.diamondbackenergy.com/company
#    -> Versuche Pfad: https://www.diamondbackenergy.com/about
#    -> Versuche Pfad: https://www.diamondbackenergy.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [FANG] ✅ Endgültiger Erfolg! 411 Zeichen extrahiert.
#
# --- [DASH] Starte Abruf: https://www.doordash.com/ ---
#    -> Versuche Pfad: https://www.doordash.com/company
#    -> Versuche Pfad: https://www.doordash.com/about
#    -> Versuche Pfad: https://www.doordash.com/investors
#    -> Versuche Pfad: https://www.doordash.com/
#
# --- [EA] Starte Abruf: https://www.ea.com ---
#    -> Versuche Pfad: https://www.ea.com/company
#    -> Versuche Pfad: https://www.ea.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [EA] ✅ Endgültiger Erfolg! 2468 Zeichen extrahiert.
#
# --- [EXC] Starte Abruf: https://www.exeloncorp.com/ ---
#    -> Versuche Pfad: https://www.exeloncorp.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [EXC] ✅ Endgültiger Erfolg! 948 Zeichen extrahiert.
#
# --- [FAST] Starte Abruf: https://www.fastenal.com/ ---
#    -> Versuche Pfad: https://www.fastenal.com/company
#    -> Versuche Pfad: https://www.fastenal.com/about
#    -> Versuche Pfad: https://www.fastenal.com/investors
#    -> Versuche Pfad: https://www.fastenal.com/
#
# --- [FTNT] Starte Abruf: http://www.fortinet.com/ ---
#    -> Versuche Pfad: http://www.fortinet.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [FTNT] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [GEHC] Starte Abruf: http://www.gehealthcare.com ---
#    -> Versuche Pfad: http://www.gehealthcare.com/company
#    -> Versuche Pfad: http://www.gehealthcare.com/about
#    -> Versuche Pfad: http://www.gehealthcare.com/investors
#    -> Versuche Pfad: http://www.gehealthcare.com/
#
# --- [GILD] Starte Abruf: https://www.gilead.com/ ---
#    -> Versuche Pfad: https://www.gilead.com/company
#    -> Versuche Pfad: https://www.gilead.com/about
#    -> Versuche Pfad: https://www.gilead.com/investors
#    -> Versuche Pfad: https://www.gilead.com/
#    -> ✅ Erfolg auf Pfad: /
# [GILD] ✅ Endgültiger Erfolg! 942 Zeichen extrahiert.
#
# --- [GFS] Starte Abruf: https://gf.com/ ---
#    -> Versuche Pfad: https://gf.com/company
#    -> Versuche Pfad: https://gf.com/about
#    -> Versuche Pfad: https://gf.com/investors
#    -> Versuche Pfad: https://gf.com/
#    -> ✅ Erfolg auf Pfad: /
# [GFS] ✅ Endgültiger Erfolg! 1332 Zeichen extrahiert.
# [HON] ❌ URL ungültig. Überspringe.
#
# --- [IDXX] Starte Abruf: http://www.idexx.com ---
#    -> Versuche Pfad: http://www.idexx.com/company
#    -> Versuche Pfad: http://www.idexx.com/about
#    -> Versuche Pfad: http://www.idexx.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [IDXX] ✅ Endgültiger Erfolg! 2557 Zeichen extrahiert.
#
# --- [INTC] Starte Abruf: https://www.intel.com ---
#    -> Versuche Pfad: https://www.intel.com/company
#    -> Versuche Pfad: https://www.intel.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [INTC] ✅ Endgültiger Erfolg! 2030 Zeichen extrahiert.
#
# --- [INTU] Starte Abruf: https://www.intuit.com/ ---
#    -> Versuche Pfad: https://www.intuit.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [INTU] ✅ Endgültiger Erfolg! 322 Zeichen extrahiert.
#
# --- [ISRG] Starte Abruf: https://www.intuitive.com ---
#    -> Versuche Pfad: https://www.intuitive.com/company
#    -> Versuche Pfad: https://www.intuitive.com/about
#    -> Versuche Pfad: https://www.intuitive.com/investors
#    -> Versuche Pfad: https://www.intuitive.com/
#
# --- [KDP] Starte Abruf: https://www.drpeppersnapplegroup.com ---
#    -> Versuche Pfad: https://www.drpeppersnapplegroup.com/company
#    -> Versuche Pfad: https://www.drpeppersnapplegroup.com/about
#    -> Versuche Pfad: https://www.drpeppersnapplegroup.com/investors
#    -> Versuche Pfad: https://www.drpeppersnapplegroup.com/
#
# --- [KLAC] Starte Abruf: https://www.kla.com/ ---
#    -> Versuche Pfad: https://www.kla.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [KLAC] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [KHC] Starte Abruf: http://www.kraftheinzcompany.com ---
#    -> Versuche Pfad: http://www.kraftheinzcompany.com/company
#    -> Versuche Pfad: http://www.kraftheinzcompany.com/about
#    -> Versuche Pfad: http://www.kraftheinzcompany.com/investors
#    -> Versuche Pfad: http://www.kraftheinzcompany.com/
#    -> ✅ Erfolg auf Pfad: /
# [KHC] ✅ Endgültiger Erfolg! 623 Zeichen extrahiert.
#
# --- [LRCX] Starte Abruf: https://www.lamresearch.com/ ---
#    -> Versuche Pfad: https://www.lamresearch.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [LRCX] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [LIN] Starte Abruf: http://www.linde.com/ ---
#    -> Versuche Pfad: http://www.linde.com/company
#    -> Versuche Pfad: http://www.linde.com/about
#    -> Versuche Pfad: http://www.linde.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [LIN] ✅ Endgültiger Erfolg! 225 Zeichen extrahiert.
#
# --- [LULU] Starte Abruf: https://shop.lululemon.com/ ---
#    -> Versuche Pfad: https://shop.lululemon.com/company
#    -> Versuche Pfad: https://shop.lululemon.com/about
#    -> Versuche Pfad: https://shop.lululemon.com/investors
#    -> Versuche Pfad: https://shop.lululemon.com/
#    -> ✅ Erfolg auf Pfad: /
# [LULU] ✅ Endgültiger Erfolg! 597 Zeichen extrahiert.
#
# --- [MAR] Starte Abruf: https://www.marriott.com.cn/ ---
#    -> Versuche Pfad: https://www.marriott.com.cn/company
#    -> Versuche Pfad: https://www.marriott.com.cn/about
#    -> Versuche Pfad: https://www.marriott.com.cn/investors
#    -> Versuche Pfad: https://www.marriott.com.cn/
#
# --- [MRVL] Starte Abruf: https://www.marvell.com/ ---
#    -> Versuche Pfad: https://www.marvell.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [MRVL] ✅ Endgültiger Erfolg! 1784 Zeichen extrahiert.
#
# --- [MELI] Starte Abruf: https://www.mercadolibre.com/ ---
#    -> Versuche Pfad: https://www.mercadolibre.com/company
#    -> Versuche Pfad: https://www.mercadolibre.com/about
#    -> Versuche Pfad: https://www.mercadolibre.com/investors
#    -> Versuche Pfad: https://www.mercadolibre.com/
#    -> ✅ Erfolg auf Pfad: /
# [MELI] ✅ Endgültiger Erfolg! 169 Zeichen extrahiert.
#
# --- [META] Starte Abruf: https://www.meta.com/ ---
#    -> Versuche Pfad: https://www.meta.com/company
#    -> Versuche Pfad: https://www.meta.com/about
#    -> Versuche Pfad: https://www.meta.com/investors
#    -> Versuche Pfad: https://www.meta.com/
#
# --- [MCHP] Starte Abruf: https://www.microchip.com/ ---
#    -> Versuche Pfad: https://www.microchip.com/company
#    -> Versuche Pfad: https://www.microchip.com/about
#    -> Versuche Pfad: https://www.microchip.com/investors
#    -> Versuche Pfad: https://www.microchip.com/
#
# --- [MU] Starte Abruf: https://www.micron.com/ ---
#    -> Versuche Pfad: https://www.micron.com/company
#    -> Versuche Pfad: https://www.micron.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [MU] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [MSFT] Starte Abruf: https://www.microsoft.com/ ---
#    -> Versuche Pfad: https://www.microsoft.com/company
#    -> Versuche Pfad: https://www.microsoft.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [MSFT] ✅ Endgültiger Erfolg! 1429 Zeichen extrahiert.
#
# --- [MSTR] Starte Abruf: https://www.microstrategy.com/ ---
#    -> Versuche Pfad: https://www.microstrategy.com/company
#    -> Versuche Pfad: https://www.microstrategy.com/about
#    -> Versuche Pfad: https://www.microstrategy.com/investors
#    -> Versuche Pfad: https://www.microstrategy.com/
#
# --- [MDLZ] Starte Abruf: https://www.mondelezinternational.com/ ---
#    -> Versuche Pfad: https://www.mondelezinternational.com/company
#    -> Versuche Pfad: https://www.mondelezinternational.com/about
#    -> Versuche Pfad: https://www.mondelezinternational.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [MDLZ] ✅ Endgültiger Erfolg! 248 Zeichen extrahiert.
#
# --- [MNST] Starte Abruf: http://www.monsterbevcorp.com/ ---
#    -> Versuche Pfad: http://www.monsterbevcorp.com/company
#    -> Versuche Pfad: http://www.monsterbevcorp.com/about
#    -> Versuche Pfad: http://www.monsterbevcorp.com/investors
#    -> Versuche Pfad: http://www.monsterbevcorp.com/
#
# --- [NFLX] Starte Abruf: https://ir.netflix.net/ ---
#    -> Versuche Pfad: https://ir.netflix.net/company
#    -> Versuche Pfad: https://ir.netflix.net/about
#    -> Versuche Pfad: https://ir.netflix.net/investors
#    -> Versuche Pfad: https://ir.netflix.net/
#
# --- [NVDA] Starte Abruf: https://www.nvidia.com/ ---
#    -> Versuche Pfad: https://www.nvidia.com/company
#    -> Versuche Pfad: https://www.nvidia.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [NVDA] ✅ Endgültiger Erfolg! 263 Zeichen extrahiert.
#
# --- [NXPI] Starte Abruf: http://www.ru.nxp.com/ ---
#    -> Versuche Pfad: http://www.ru.nxp.com/company
#    -> Versuche Pfad: http://www.ru.nxp.com/about
#    -> Versuche Pfad: http://www.ru.nxp.com/investors
#    -> Versuche Pfad: http://www.ru.nxp.com/
#
# --- [ORLY] Starte Abruf: http://www.oreillyauto.com/ ---
#    -> Versuche Pfad: http://www.oreillyauto.com/company
#    -> Versuche Pfad: http://www.oreillyauto.com/about
#    -> Versuche Pfad: http://www.oreillyauto.com/investors
#    -> Versuche Pfad: http://www.oreillyauto.com/
#
# --- [ODFL] Starte Abruf: http://www.odfl.com/ ---
#    -> Versuche Pfad: http://www.odfl.com/company
#    -> Versuche Pfad: http://www.odfl.com/about
#    -> Versuche Pfad: http://www.odfl.com/investors
#    -> Versuche Pfad: http://www.odfl.com/
#    -> ✅ Erfolg auf Pfad: /
# [ODFL] ✅ Endgültiger Erfolg! 735 Zeichen extrahiert.
#
# --- [ON] Starte Abruf: https://www.onsemi.com/ ---
#    -> Versuche Pfad: https://www.onsemi.com/company
#    -> Versuche Pfad: https://www.onsemi.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [ON] ✅ Endgültiger Erfolg! 891 Zeichen extrahiert.
#
# --- [PCAR] Starte Abruf: http://www.paccar.com/ ---
#    -> Versuche Pfad: http://www.paccar.com/company
#    -> Versuche Pfad: http://www.paccar.com/about
#    -> Versuche Pfad: http://www.paccar.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [PCAR] ✅ Endgültiger Erfolg! 1367 Zeichen extrahiert.
#
# --- [PLTR] Starte Abruf: https://www.palantir.com/ ---
#    -> Versuche Pfad: https://www.palantir.com/company
#    -> Versuche Pfad: https://www.palantir.com/about
#    -> Versuche Pfad: https://www.palantir.com/investors
#    -> Versuche Pfad: https://www.palantir.com/
#
# --- [PANW] Starte Abruf: https://www.paloaltonetworks.com ---
#    -> Versuche Pfad: https://www.paloaltonetworks.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [PANW] ✅ Endgültiger Erfolg! 3000 Zeichen extrahiert.
#
# --- [PAYX] Starte Abruf: http://www.paychex.com/ ---
#    -> Versuche Pfad: http://www.paychex.com/company
#    -> Versuche Pfad: http://www.paychex.com/about
#    -> Versuche Pfad: http://www.paychex.com/investors
#    -> ✅ Erfolg auf Pfad: /investors
# [PAYX] ✅ Endgültiger Erfolg! 500 Zeichen extrahiert.
#
# --- [PYPL] Starte Abruf: https://www.paypal.com/ ---
#    -> Versuche Pfad: https://www.paypal.com/company
#    -> Versuche Pfad: https://www.paypal.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [PYPL] ✅ Endgültiger Erfolg! 1482 Zeichen extrahiert.
#
# --- [PDD] Starte Abruf: https://www.pddholdings.com/ ---
#    -> Versuche Pfad: https://www.pddholdings.com/company
#    -> Versuche Pfad: https://www.pddholdings.com/about
#    -> Versuche Pfad: https://www.pddholdings.com/investors
#    -> Versuche Pfad: https://www.pddholdings.com/
#    -> ✅ Erfolg auf Pfad: /
# [PDD] ✅ Endgültiger Erfolg! 138 Zeichen extrahiert.
#
# --- [PEP] Starte Abruf: https://pepsico.com ---
#    -> Versuche Pfad: https://pepsico.com/company
#    -> Versuche Pfad: https://pepsico.com/about
#    -> Versuche Pfad: https://pepsico.com/investors
#    -> Versuche Pfad: https://pepsico.com/
#
# --- [QCOM] Starte Abruf: https://www.qualcomm.com/ ---
#    -> Versuche Pfad: https://www.qualcomm.com/company
#    -> Versuche Pfad: https://www.qualcomm.com/about
#    -> Versuche Pfad: https://www.qualcomm.com/investors
#    -> Versuche Pfad: https://www.qualcomm.com/
#
# --- [REGN] Starte Abruf: https://www.regeneron.com/ ---
#    -> Versuche Pfad: https://www.regeneron.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [REGN] ✅ Endgültiger Erfolg! 2753 Zeichen extrahiert.
#
# --- [ROP] Starte Abruf: http://www.roperind.com/ ---
#    -> Versuche Pfad: http://www.roperind.com/company
#    -> Versuche Pfad: http://www.roperind.com/about
#    -> Versuche Pfad: http://www.roperind.com/investors
#    -> Versuche Pfad: http://www.roperind.com/
#    -> ✅ Erfolg auf Pfad: /
# [ROP] ✅ Endgültiger Erfolg! 136 Zeichen extrahiert.
#
# --- [ROST] Starte Abruf: https://www.rossstores.com/ ---
#    -> Versuche Pfad: https://www.rossstores.com/company
#    -> Versuche Pfad: https://www.rossstores.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [ROST] ✅ Endgültiger Erfolg! 1304 Zeichen extrahiert.
#
# --- [SHOP] Starte Abruf: https://www.shopify.com/ ---
#    -> Versuche Pfad: https://www.shopify.com/company
#    -> Versuche Pfad: https://www.shopify.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [SHOP] ✅ Endgültiger Erfolg! 1562 Zeichen extrahiert.
# [SOLS] ❌ URL ungültig. Überspringe.
#
# --- [SBUX] Starte Abruf: https://www.starbucks.com/ ---
#    -> Versuche Pfad: https://www.starbucks.com/company
#    -> Versuche Pfad: https://www.starbucks.com/about
#    -> Versuche Pfad: https://www.starbucks.com/investors
#    -> Versuche Pfad: https://www.starbucks.com/
#    -> ✅ Erfolg auf Pfad: /
# [SBUX] ✅ Endgültiger Erfolg! 1530 Zeichen extrahiert.
#
# --- [SNPS] Starte Abruf: https://www.synopsys.com/ ---
#    -> Versuche Pfad: https://www.synopsys.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [SNPS] ✅ Endgültiger Erfolg! 915 Zeichen extrahiert.
#
# --- [TMUS] Starte Abruf: https://www.t-mobile.com/ ---
#    -> Versuche Pfad: https://www.t-mobile.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [TMUS] ✅ Endgültiger Erfolg! 568 Zeichen extrahiert.
#
# --- [TTWO] Starte Abruf: http://www.take2games.com ---
#    -> Versuche Pfad: http://www.take2games.com/company
#    -> Versuche Pfad: http://www.take2games.com/about
#    -> Versuche Pfad: http://www.take2games.com/investors
#    -> Versuche Pfad: http://www.take2games.com/
#    -> ✅ Erfolg auf Pfad: /
# [TTWO] ✅ Endgültiger Erfolg! 878 Zeichen extrahiert.
#
# --- [TSLA] Starte Abruf: https://www.tesla.com/ ---
#    -> Versuche Pfad: https://www.tesla.com/company
#    -> Versuche Pfad: https://www.tesla.com/about
#    -> Versuche Pfad: https://www.tesla.com/investors
#    -> Versuche Pfad: https://www.tesla.com/
#
# --- [TXN] Starte Abruf: https://www.ti.com/ ---
#    -> Versuche Pfad: https://www.ti.com/company
#    -> Versuche Pfad: https://www.ti.com/about
#    -> Versuche Pfad: https://www.ti.com/investors
#    -> Versuche Pfad: https://www.ti.com/
#    -> ✅ Erfolg auf Pfad: /
# [TXN] ✅ Endgültiger Erfolg! 1890 Zeichen extrahiert.
#
# --- [TRI] Starte Abruf: https://www.thomsonreuters.com/en.html ---
#    -> Versuche Pfad: https://www.thomsonreuters.com/company
#    -> Versuche Pfad: https://www.thomsonreuters.com/about
#    -> ✅ Erfolg auf Pfad: /about
# [TRI] ✅ Endgültiger Erfolg! 2066 Zeichen extrahiert.
# [TTD] ❌ URL ungültig. Überspringe.
#
# --- [VRSK] Starte Abruf: http://www.verisk.com/ ---
#    -> Versuche Pfad: http://www.verisk.com/company
#    -> Versuche Pfad: http://www.verisk.com/about
#    -> Versuche Pfad: http://www.verisk.com/investors
#    -> Versuche Pfad: http://www.verisk.com/
#    -> ✅ Erfolg auf Pfad: /
# [VRSK] ✅ Endgültiger Erfolg! 1371 Zeichen extrahiert.
#
# --- [VRTX] Starte Abruf: https://www.vrtx.com/ ---
#    -> Versuche Pfad: https://www.vrtx.com/company
#    -> Versuche Pfad: https://www.vrtx.com/about
#    -> Versuche Pfad: https://www.vrtx.com/investors
#    -> Versuche Pfad: https://www.vrtx.com/
#
# --- [WBD] Starte Abruf: http://www.wbd.com ---
#    -> Versuche Pfad: http://www.wbd.com/company
#    -> Versuche Pfad: http://www.wbd.com/about
#    -> Versuche Pfad: http://www.wbd.com/investors
#    -> Versuche Pfad: http://www.wbd.com/
#    -> ✅ Erfolg auf Pfad: /
# [WBD] ✅ Endgültiger Erfolg! 784 Zeichen extrahiert.
#
# --- [WDAY] Starte Abruf: https://www.workday.com/ ---
#    -> Versuche Pfad: https://www.workday.com/company
#    -> Versuche Pfad: https://www.workday.com/about
#    -> Versuche Pfad: https://www.workday.com/investors
#    -> Versuche Pfad: https://www.workday.com/
#    -> ✅ Erfolg auf Pfad: /
# [WDAY] ✅ Endgültiger Erfolg! 1193 Zeichen extrahiert.
#
# --- [XEL] Starte Abruf: https://my.xcelenergy.com/ ---
#    -> Versuche Pfad: https://my.xcelenergy.com/company
#    -> Versuche Pfad: https://my.xcelenergy.com/about
#    -> Versuche Pfad: https://my.xcelenergy.com/investors
#    -> Versuche Pfad: https://my.xcelenergy.com/
#
# --- [ZS] Starte Abruf: https://www.zscaler.com/ ---
#    -> Versuche Pfad: https://www.zscaler.com/company
#    -> ✅ Erfolg auf Pfad: /company
# [ZS] ✅ Endgültiger Erfolg! 2259 Zeichen extrahiert.
#
# ====================================
# Datenextraktion abgeschlossen. Resultate gespeichert in: nasdaq100_company_texts_V2.csv
# ====================================
