# %%
import pandas as pd
import re
import os

# 1. Daten laden
df = pd.read_csv("WikiNasdaq_100_constituents.csv")

# 2. Relevante Spalten auswählen
df_assets = df[['Company', 'Ticker', 'Website']].copy()

# 3. Domain aus der Website-URL extrahieren
# Wir verwenden eine reguläre Expression, um den Domain-Namen zu isolieren.
def extract_domain(url):
    if pd.isna(url):
        return None
    # Entfernt 'http(s)://', 'www.' und alles nach dem ersten '/'
    match = re.search(r'https?://(?:www\.)?([^/]+)', url)
    return match.group(1).split('/')[0] if match else None

df_assets['Domain'] = df_assets['Website'].apply(extract_domain)

# 4. Bereinigen und NaN-Werte füllen (wichtig für die API-Abfrage)
# Bei fehlender Domain verwenden wir das Ticker-Symbol als Fallback
df_assets['Query_Domain'] = df_assets['Domain'].fillna(df_assets['Ticker'])
df_assets['Query_Ticker'] = df_assets['Ticker']

# 5. Resultat anzeigen und speichern
print("Vorbereitete Daten für API-Abfrage (Head):")
print(df_assets[['Company', 'Query_Ticker', 'Query_Domain']].head())

# Speichern der bereinigten Daten als neue CSV-Datei
output_file = 'nasdaq100_api_queries.csv'
df_assets[['Company', 'Query_Ticker', 'Query_Domain']].to_csv(output_file, index=False)
print(f"\nDaten gespeichert unter: {output_file}")
# Out:
# Vorbereitete Daten für API-Abfrage (Head):
#                    Company Query_Ticker Query_Domain
# 0               Adobe Inc.         ADBE    adobe.com
# 1   Advanced Micro Devices          AMD      amd.com
# 2                   Airbnb         ABNB   airbnb.com
# 3  Alphabet Inc. (Class A)        GOOGL        GOOGL
# 4  Alphabet Inc. (Class C)         GOOG         GOOG
#
# Daten gespeichert unter: nasdaq100_api_queries.csv

# %%
import requests

LOGO_DEV_PUBLIC_KEY = 'pk_e39AWXK1TbGed73t_mPsIw'

def get_company_logo(ticker):
    url = f"https://img.logo.dev/ticker/{ticker}?token={LOGO_DEV_PUBLIC_KEY}"
    response = requests.get(url)
    return response.content

# Tesla Ticker
ticker = "TSLA"

# Abrufen des Logos
logo_content = get_company_logo(ticker)

# Speichern des Logos in einer Datei
with open("tesla_logo.png", "wb") as logo_file:
    logo_file.write(logo_content)

print("Das Tesla-Logo wurde als 'tesla_logo.png' gespeichert.")
# Out:
# Das Tesla-Logo wurde als 'tesla_logo.png' gespeichert.

# %%
import os
import csv
import requests

LOGO_DEV_PUBLIC_KEY = 'pk_e39AWXK1TbGed73t_mPsIw'

def get_company_logo(ticker):
    url = f"https://img.logo.dev/ticker/{ticker}?token={LOGO_DEV_PUBLIC_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.content
    else:
        print(f"Fehler beim Abrufen des Logos für {ticker}: {response.status_code}")
        return None

# Ordner für Logos erstellen
output_folder = "nasdaq_logos"
os.makedirs(output_folder, exist_ok=True)

# CSV-Datei mit Tickersymbolen einlesen
csv_file = "/Users/vincentgoldmann/HDMDaten/DataScience_Sandbox/WikiNasdaq_100_constituents.csv"
with open(csv_file, newline='', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        ticker = row['Ticker']  # Spalte mit dem Ticker-Symbol
        print(f"Abrufen des Logos für {ticker}...")
        logo_content = get_company_logo(ticker)
        if logo_content:
            # Logo speichern
            logo_path = os.path.join(output_folder, f"{ticker}.png")
            with open(logo_path, "wb") as logo_file:
                logo_file.write(logo_content)
            print(f"Logo für {ticker} gespeichert.")
        else:
            print(f"Logo für {ticker} konnte nicht abgerufen werden.")

print("Alle Logos wurden abgerufen und gespeichert.")
# Out:
# Abrufen des Logos für ADBE...
# Logo für ADBE gespeichert.
# Abrufen des Logos für AMD...
# Logo für AMD gespeichert.
# Abrufen des Logos für ABNB...
# Logo für ABNB gespeichert.
# Abrufen des Logos für GOOGL...
# Logo für GOOGL gespeichert.
# Abrufen des Logos für GOOG...
# Logo für GOOG gespeichert.
# Abrufen des Logos für AMZN...
# Logo für AMZN gespeichert.
# Abrufen des Logos für AEP...
# Logo für AEP gespeichert.
# Abrufen des Logos für AMGN...
# Logo für AMGN gespeichert.
# Abrufen des Logos für ADI...
# Logo für ADI gespeichert.
# Abrufen des Logos für AAPL...
# Logo für AAPL gespeichert.
# Abrufen des Logos für AMAT...
# Logo für AMAT gespeichert.
# Abrufen des Logos für APP...
# Logo für APP gespeichert.
# Abrufen des Logos für ARM...
# Logo für ARM gespeichert.
# Abrufen des Logos für ASML...
# Logo für ASML gespeichert.
# Abrufen des Logos für AZN...
# Logo für AZN gespeichert.
# Abrufen des Logos für TEAM...
# Logo für TEAM gespeichert.
# Abrufen des Logos für ADSK...
# Logo für ADSK gespeichert.
# Abrufen des Logos für ADP...
# Logo für ADP gespeichert.
# Abrufen des Logos für AXON...
# Logo für AXON gespeichert.
# Abrufen des Logos für BKR...
# Logo für BKR gespeichert.
# Abrufen des Logos für BIIB...
# Logo für BIIB gespeichert.
# Abrufen des Logos für BKNG...
# Logo für BKNG gespeichert.
# Abrufen des Logos für AVGO...
# Logo für AVGO gespeichert.
# Abrufen des Logos für CDNS...
# Logo für CDNS gespeichert.
# Abrufen des Logos für CDW...
# Logo für CDW gespeichert.
# Abrufen des Logos für CHTR...
# Logo für CHTR gespeichert.
# Abrufen des Logos für CTAS...
# Logo für CTAS gespeichert.
# Abrufen des Logos für CSCO...
# Logo für CSCO gespeichert.
# Abrufen des Logos für CCEP...
# Logo für CCEP gespeichert.
# Abrufen des Logos für CTSH...
# Logo für CTSH gespeichert.
# Abrufen des Logos für CMCSA...
# Logo für CMCSA gespeichert.
# Abrufen des Logos für CEG...
# Logo für CEG gespeichert.
# Abrufen des Logos für CPRT...
# Logo für CPRT gespeichert.
# Abrufen des Logos für CSGP...
# Logo für CSGP gespeichert.
# Abrufen des Logos für COST...
# Logo für COST gespeichert.
# Abrufen des Logos für CRWD...
# Logo für CRWD gespeichert.
# Abrufen des Logos für CSX...
# Logo für CSX gespeichert.
# Abrufen des Logos für DDOG...
# Logo für DDOG gespeichert.
# Abrufen des Logos für DXCM...
# Logo für DXCM gespeichert.
# Abrufen des Logos für FANG...
# Logo für FANG gespeichert.
# Abrufen des Logos für DASH...
# Logo für DASH gespeichert.
# Abrufen des Logos für EA...
# Logo für EA gespeichert.
# Abrufen des Logos für EXC...
# Logo für EXC gespeichert.
# Abrufen des Logos für FAST...
# Logo für FAST gespeichert.
# Abrufen des Logos für FTNT...
# Logo für FTNT gespeichert.
# Abrufen des Logos für GEHC...
# Logo für GEHC gespeichert.
# Abrufen des Logos für GILD...
# Logo für GILD gespeichert.
# Abrufen des Logos für GFS...
# Logo für GFS gespeichert.
# Abrufen des Logos für HON...
# Logo für HON gespeichert.
# Abrufen des Logos für IDXX...
# Logo für IDXX gespeichert.
# Abrufen des Logos für INTC...
# Logo für INTC gespeichert.
# Abrufen des Logos für INTU...
# Logo für INTU gespeichert.
# Abrufen des Logos für ISRG...
# Logo für ISRG gespeichert.
# Abrufen des Logos für KDP...
# Logo für KDP gespeichert.
# Abrufen des Logos für KLAC...
# Logo für KLAC gespeichert.
# Abrufen des Logos für KHC...
# Logo für KHC gespeichert.
# Abrufen des Logos für LRCX...
# Logo für LRCX gespeichert.
# Abrufen des Logos für LIN...
# Logo für LIN gespeichert.
# Abrufen des Logos für LULU...
# Logo für LULU gespeichert.
# Abrufen des Logos für MAR...
# Logo für MAR gespeichert.
# Abrufen des Logos für MRVL...
# Logo für MRVL gespeichert.
# Abrufen des Logos für MELI...
# Logo für MELI gespeichert.
# Abrufen des Logos für META...
# Logo für META gespeichert.
# Abrufen des Logos für MCHP...
# Logo für MCHP gespeichert.
# Abrufen des Logos für MU...
# Logo für MU gespeichert.
# Abrufen des Logos für MSFT...
# Logo für MSFT gespeichert.
# Abrufen des Logos für MSTR...
# Logo für MSTR gespeichert.
# Abrufen des Logos für MDLZ...
# Logo für MDLZ gespeichert.
# Abrufen des Logos für MNST...
# Logo für MNST gespeichert.
# Abrufen des Logos für NFLX...
# Logo für NFLX gespeichert.
# Abrufen des Logos für NVDA...
# Logo für NVDA gespeichert.
# Abrufen des Logos für NXPI...
# Logo für NXPI gespeichert.
# Abrufen des Logos für ORLY...
# Logo für ORLY gespeichert.
# Abrufen des Logos für ODFL...
# Logo für ODFL gespeichert.
# Abrufen des Logos für ON...
# Logo für ON gespeichert.
# Abrufen des Logos für PCAR...
# Logo für PCAR gespeichert.
# Abrufen des Logos für PLTR...
# Logo für PLTR gespeichert.
# Abrufen des Logos für PANW...
# Logo für PANW gespeichert.
# Abrufen des Logos für PAYX...
# Logo für PAYX gespeichert.
# Abrufen des Logos für PYPL...
# Logo für PYPL gespeichert.
# Abrufen des Logos für PDD...
# Logo für PDD gespeichert.
# Abrufen des Logos für PEP...
# Logo für PEP gespeichert.
# Abrufen des Logos für QCOM...
# Logo für QCOM gespeichert.
# Abrufen des Logos für REGN...
# Logo für REGN gespeichert.
# Abrufen des Logos für ROP...
# Logo für ROP gespeichert.
# Abrufen des Logos für ROST...
# Logo für ROST gespeichert.
# Abrufen des Logos für SHOP...
# Logo für SHOP gespeichert.
# Abrufen des Logos für SOLS...
# Logo für SOLS gespeichert.
# Abrufen des Logos für SBUX...
# Logo für SBUX gespeichert.
# Abrufen des Logos für SNPS...
# Logo für SNPS gespeichert.
# Abrufen des Logos für TMUS...
# Logo für TMUS gespeichert.
# Abrufen des Logos für TTWO...
# Logo für TTWO gespeichert.
# Abrufen des Logos für TSLA...
# Logo für TSLA gespeichert.
# Abrufen des Logos für TXN...
# Logo für TXN gespeichert.
# Abrufen des Logos für TRI...
# Logo für TRI gespeichert.
# Abrufen des Logos für TTD...
# Logo für TTD gespeichert.
# Abrufen des Logos für VRSK...
# Logo für VRSK gespeichert.
# Abrufen des Logos für VRTX...
# Logo für VRTX gespeichert.
# Abrufen des Logos für WBD...
# Logo für WBD gespeichert.
# Abrufen des Logos für WDAY...
# Logo für WDAY gespeichert.
# Abrufen des Logos für XEL...
# Logo für XEL gespeichert.
# Abrufen des Logos für ZS...
# Logo für ZS gespeichert.
# Alle Logos wurden abgerufen und gespeichert.
